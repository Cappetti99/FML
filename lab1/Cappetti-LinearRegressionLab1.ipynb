# %% [markdown]
# # Linear Regression in Practice
#
# In this lab we will work through an extended example of exploratory data analysis and supervised machine learning using the California Housing Price Dataset. This dataset consists of data about housing characteristics and prices in many districts of the state of California. The **task** this dataset asks us to solve is estimating the median house value in a district from a set of independent housing characteristics.
#
# **Note**: the exercises are inline in this notebook and *not* at the end. The exercises will ask you to write some code and sometimes to provide some analysis of your findings in Markdown cells at the end of the exercise.
#
# The main objectives of this laboratory are:
# + For you to gain familiarity with using Python for numerical programming in Jupyter Notebooks, Google Colaboratory, or *[INSERT TOOL OF CHOICE]*.
# + For you to gain familiarity with working with data in Numpy, Pandas, and Scikit-learn.
# + For you to learn how to use *visualization* as a tool for understanding the nature of machine learning problems and gain insight into potential solutions.
# + To learn to use Scikit-learn to solve simple univariate regression problems and validate your solutions.
# + To learn the value of *encapsulation* and *abstraction* of pipeline code for making experiments *reproducible*.
#
# ---
# ---
#
# # CODE OF CONDUCT V1.0
#
# This Code of Conduct outlines principles for the ethical and transparent use of Large Language Models (LLMs) and existing and internet resources, ensuring integrity and accountability in your laboratory submissions. This first version of the FML Laboratory Code of Conduct was developed in a brainstorming session with **ChatGPT Version 2**, modifying its proposal to the specifics of the FML Laboratories and concentrating on the transparent collaboration with classmates and transparent use of LLMs.
#
# #### **1. Transparency in LLM Use**
# - **Clear Disclosure:** Explicitly state when Large Language Models (LLMs) are used in any part of the process, including data analysis, code generation, or writing.
# - **Model Limitations:** Acknowledge the inherent limitations of LLMs, such as potential biases, and make clear where human intervention was applied to verify results or to modify/augment produced code.
#
# #### **2. Proper Attribution and Documentation**
# - **Attribution:** Provide appropriate citations and credits for all external resources, including code, data, and models.
# - **Clear Documentation:** Maintain detailed records of tools, methods, and models used, ensuring transparency and reproducibility in your submitted laboratory solutions.
#
# #### **3. Collaboration and Individual Work**
# - **Sharing Solutions:** While collaboration and discussing ideas with classmates are encouraged, solutions to assignments or projects should be your own. Do not copy or submit work created by others, including code or models, as your own.
# - **Submission Integrity:** All submitted work must reflect your own understanding and effort. If external tools, LLMs, online resources, or code from your classmates were used, they must be properly documented, but the final submission must be an individual effort.
#
# #### **4. Accountability**
# Non-compliance with these guidelines will be subject to review by the course exam commission, with possible disciplinary actions.
#
# ---
# ---
#
# ## Part 1: Warming Up
#
# In this first set of exercises we will analyze our dataset and build a simple linear regression pipeline. This is a fairly typical task that is asked of anyone working with Data Science: Here is some data, do something useful with it!

# %% [markdown]
# ### Step 1: Data Modeling
#
# OK, let's get started. The first thing we want to do is get our dataset loaded and start to get a feel for it. This is always a good idea -- we *play* with the data first in order to get a better understanding of it.

# %%
# Initial imports -- these are fairly standard.
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Import the function that will download the dataset.
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# Load the sklearn version of the California Housing dataset.
ds = fetch_california_housing()

# %% [markdown]
# ### Exercise 1a: Poking Around
#
# Spend some time looking at the elements of the `ds` we just loaded (it's a python `dict`). Find the description of the dataset and make sure you understand what the features are and what the targets variable is. **Hints**: to get the keys of the dictionary, use: `ds.keys()`.
#
# We are going to construct a Pandas `DataFrame` in the next exercise. Where can you get reasonable column names from the sklearn dataset object?

# %%
print(ds.keys())
print(ds.DESCR)
print(ds.data.shape)   
print(ds.feature_names)
print(ds.target.shape)
print(ds.target_names)
print(ds.data)
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# (20640,)
# ['MedHouseVal']
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %% [markdown]
# **Analysis:** In this analysis, we explored the California Housing dataset using scikit-learn.
# This dataset is commonly used for regression tasks, where the goal is to predict
# the median house value for California districts based on various features:
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None

# %% [markdown]
# ### Exercise 1b: Creating a Pandas DataFrame
#
# OK, now we can create the `DataFrame` to hold our independent variables and a `Series` to hold the target values. Make sure you use good column names when constructing the `DataFrame`. Some relevant documentation: [pandas.DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) and [pandas.Series](https://pandas.pydata.org/docs/reference/api/pandas.Series.html).

# %%
# Code to build the DataFrame here
df = pd.DataFrame(data = ds.data, columns = ds.feature_names)
print(df)

# Code to build the target Series here (replace None)
targets = pd.Series(ds.target)
print(targets)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Length: 20640, dtype: float64

# %% [markdown]
# ### Exercise 1c: Examining the Data
#
# Study the *descriptive statistics* of the data. Do you notice anything "strange" about any of the features? Are the features scaled similarly? **Hint**: Use the `.describe()` method on the DataFrame you created.

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %% [markdown]
# **Analysis:** The "count" row in the summary statistics is the same for all columns,
# indicating that there are no missing values in the dataset. This is a positive aspect as missing data can often complicate analysis.
#
# Observations: The "AveRooms" feature has a maximum value that appears significantly higher than the 75th percentile.
# This suggests the presence of outliers or extreme values in the dataset.
# Similarly, the "AveBedrms" feature also has a maximum value much higher than the 75th percentile, indicating potential outliers.
#
# We can also see al lot of variance in the inputs.

# %%
targets.describe()
# Out:
# count    20640.000000
# mean         2.068558
# std          1.153956
# min          0.149990
# 25%          1.196000
# 50%          1.797000
# 75%          2.647250
# max          5.000010
# dtype: float64

# %% [markdown]
# **Analysis**: Our target variables are distributed reasonably well (at least in the first-and second-order sense), which mean and standard deviation in the same range.

# %% [markdown]
# ---
# ### Step 2: Visualization
#
# OK, now that we have a bit of a *feel* for our data, let's get a better idea about it through visualization.

# %% [markdown]
# ### Exercise 2a: Visualizing the Target
# Create a plot to study the **distribution** of our target values. The best tool for that is a **histogram**. Search for this functionality in the Matplotlib documentation.
#
# **Note**: In addition to *histograms*, try out the Seaborn function `distplot`.

# %%
targets.hist(bins=16, edgecolor='black') #Pandas has a hist method that allows you to make a histogram
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 8))
plt.hist(targets, bins=16, edgecolor='black')
plt.hist(targets, bins=30, edgecolor='black')
plt.show()

plt.figure(figsize=(10, 8))
sns.histplot(targets, bins=16, kde=True, color='lightblue')

plt.title('Targets')
plt.show()

# %% [markdown]
# **Analysis:** The graphic above shows the distribution of the target values. We can see that there's a peak at the value 5. This is caused by the fact that we group all values higher than 5 together.  The result is a Gaussian-like distribution, with a long-is tail.
#
# The first one is printed with Pandas, the second part with Matplotlib.
#
# **Note**: If we increase the value of the bins we will see a distribution with lower high in density because we split the values into more bins. We can see this well in the first image, where the blue histogram has 16 bins and the orange one 30.

# %% [markdown]
# ### Exercise 2b: Subplots
# Now create a multi-plot figure to visualize the distributions of **all** of the independent features in the dataset. Make sure you use `figsize=` to resize the figure appropriately.
#
# A few things that will help with this:
# + If you want to index columns by **integer** indices, use the `.iloc()` method (e.g. `df.iloc[:,1]`).
# + If you extract a column as a `Series` from a `DataFrame`, you can recover its name with the `name` attribute.
# + Encapsulate you plotting code in a **function** you can call later.
#
# **Super Hint**: Pandas already has this functionality **built-in**. If you can find it, use it!

# %%
plt.figure(figsize=(15, 15))
for (i, col) in enumerate(df.columns):
    plt.subplot(3, 3, i+1)  # plot on grid 3x3
    plt.hist(df[col], 30, edgecolor='black')
    plt.title(df[col].name)

# %% [markdown]
# **Analysis:** Several input features are drammatically skewed due to outliers (this is documented in the ds.DESCR). Other more reasonable, with Gaussian or simple binomial distribution (e.g. Latitude and Longitude).
# Also, if the histogram is scaled like this, it means that they have at least one value on the far right.

# %%
plt.scatter(df.Longitude, df.Latitude, c=targets, cmap='hot') 
plt.show()

# %% [markdown]
# **Analysis:** The x-axis (X) represents longitude, with values ranging from about -124 to -114.
# The y-axis (Y) represents latitude, with values ranging from about 32 to 42.
#
# The parameter `c=targets` indicates that the points are colored according to the housing price variable.
# The color of the `hot` scale varies from yellow (for higher values) to dark red or black (for lower values). Thus, yellow/light colored dots represent areas with higher prices, while dark red/black dots represent lower prices.
#
# A concentration of dots can be seen in Southern California (Los Angeles and San Diego area) and San Francisco Bay Area, suggesting higher housing density (and thus more data in these areas).
# Yellow dots, indicating higher values (potentially higher housing prices), appear to be concentrated along the coast, especially in the Los Angeles and San Francisco Bay areas.

# %% [markdown]
# ---
# ---
# ## Step 3: Split you Data
#
# A very important step. Now we will split our `DataFrame` into training and testing splits.
#
# ### Exercise 3.1: Create a Split
# Now we need to create our training and testing splits. Read the documentation for `sklearn.model_selection.train_test_split()`. Use this function to create a **training** split with 75% of the data, and a **test** split with 25% of the data.

# %%
from sklearn.model_selection import train_test_split

# Split data into 75-25 train/test split
(Xtr, Xte, ytr, yte) = train_test_split(df, targets, test_size=0.25) #Every time I change the values I fetch, to avoid this you can use a seed

print("Test Set shape:", Xte.shape)
print("Training Set shape:", Xtr.shape)
# Out:
# Test Set shape: (5160, 8)
# Training Set shape: (15480, 8)

# %% [markdown]
# **Analysis:**
# The **train_test** parameter specifies the proportion of the dataset to include in the test split. test_size=0.25 means that 25% of the data will be used for test, and the remaining 75% will be used for training.
# The purpose of splitting the data into training and testing sets is to evaluate how well your machine learning model generalizes to new, unseen data.
# Also, every time we go to run the code we will create a new dataset that is used for test and train, if one wanted to avoid this introduce a seed (in this function with the parameter random_state), so that we always work on the same data division.

# %% [markdown]
# ### Exercise 3.2: Fit a LinearRegression
# Finally some machine learning. Study the documentation for `class sklearn.linear_model.LinearRegression`. Then write some code to fit a linear regression model to your **training** split. Try out your model by computing predictions on some data (use the `model.predict()` method).

# %%
from sklearn.linear_model import LinearRegression

# Create a linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(Xtr, ytr)

# Predict the test data
y_pred = model.predict(Xte)

model.coef_

model.intercept_

print("Previsioni sui dati di test:", y_pred)
print("---------------")
print("coef:", model.coef_)
print("---------------")
print("intercept", model.intercept_)
print("---------------")

print("sum", model.coef_ @ Xte.T + model.intercept_)
# Out:
# Previsioni sui dati di test: [ 1.79695959  2.96213351  1.65593315 ...  2.33183677  2.58817474
#  -0.15882496]
# ---------------
# coef: [ 4.29530472e-01  9.82691910e-03 -1.00347873e-01  5.97513768e-01
#  -2.18072864e-06 -3.35482084e-03 -4.21753524e-01 -4.34859028e-01]
# ---------------
# intercept -36.94262728572494
# ---------------
# sum 13455    1.796960
# 18032    2.962134
# 4136     1.655933
# 6908     2.229576
# 18814    0.087057
#            ...
# 5330     2.328095
# 2224     2.045687
# 8954     2.331837
# 20193    2.588175
# 9668    -0.158825
# Length: 5160, dtype: float64

# %% [markdown]
# **Analysis:** _model_ = LinearRegression():  This row creates an instance of the linear regression model. In scikit-learn, the LinearRegression class represents a linear regression model, which can be either simple (with a single independent variable) or multiple (with multiple independent variables). Linear regression attempts to establish a linear relationship between a dependent variable (target) and one or more independent variables (feature).
#
# After creating the model, the fit() method is used to train it on the training data. The model learns the linear relationship between the features (Xtr) and the target (ytr) and calculates the coefficients (the feature weights) and the intercept (the bias).
#
# `Xtr`: The training dataset that contains the independent variables (features) used to make predictions. These are the features that you think are related to the target (e.g., age, income, etc.).
#
# `ytr`: The training data set containing the dependent variable (target). It represents the value that the model tries to predict (e.g., the price of a house, a test score, etc.).
# The result is that after training, the model “learned” the parameters of the linear function that best describes the relationship between Xtr and ytr.
#
# _model.predict(Xte)_: this method uses the trained model to make predictions about a new dataset, Xte, which contains features from the test or validation dataset. The model applies the coefficients and the intercept it learned during training to predict the values of the dependent (target) variable associated with Xte.
#
# The result is that y_pred contains the values predicted by the model for the test dataset. These values can be compared with the actual values of y to evaluate the accuracy of the predictions.
#
# In linear regression, the *model.coef* and *model.intercept* attributes provide information about the coefficients of the linear equation that the model has learned during training.

# %% [markdown]
# ### Exercise 3.3: Evaluate your Model
# Write some code to compute the root mean-squared error (RMSE) and mean absolute error (MAE) for you model predictions. Try it on both the **test** and **training** splits.

# %%
def mae(y_true, y_pred):
    return (y_true - y_pred).abs().mean()

def rmse(y_true, y_pred):
    return np.sqrt(((y_true - y_pred)**2).mean())

# %%
preds_train = model.predict(Xtr)
preds_test = model.predict(Xte)

print(f'MAE on Train: {mae(ytr, preds_train)}')
print(f'RMSE on Train: {rmse(ytr, preds_train)}')
print(f'MAE on Test: {mae(yte, preds_test)}')
print(f'RMSE on Test: {rmse(yte, preds_test)}')
# Out:
# MAE on Train: 0.5306846171415323
# RMSE on Train: 0.7244669315785398
# MAE on Test: 0.5372155321796149
# RMSE on Test: 0.7234055227991281

# %% [markdown]
# **Analysis:** The difference in performance is due to the fact that the test set is different from the training set, and the model is trained on the training set and tested on the test set.
#
# If I split the data with 100% for training and 0% for testing, the RMSE and MAE on the training set are close to 0: these results indicate a typical case of overfitting. Overfitting occurs when a model becomes too specialized in fitting the training data but fails to capture general patterns that apply to new examples. As a result, the model's performance on the training set is excellent (even perfect), but its performance on the test set is poor.
#
# If I split the data with 75% for training and 25% for testing, the results are the best.
#
# If I split the data with 50% for training and 50% for testing, the values are still low, but higher than in the previous case.
#
# If I split the data with 25% for training and 75% for testing, the values are higher because the model does not have enough data to generalize.
#
# RMSE is a measure of the average magnitude of errors between the predicted values and the actual values (targets) in the training set. It quantifies how far off, on average, the model’s predictions are from the actual values.
# MAE is another measure of the average magnitude of errors between the predicted values and the actual values in the training set, but it does not consider the direction of the errors (whether they are overestimates or underestimates).

# %% [markdown]
# ### Exercise 3.4: Visualizing the Results
# Now I want you to write a function that makes a **residual plot** of the data and the model predictions. This plot should show, for each data point, the **signed error** (i.e. y - predicted) of the model prediction. Do you notice any **patterns** in the errors? Can you link this to previous analyses you made?

# %%
(Xtr, Xte, ytr, yte) = train_test_split(df, targets, train_size=0.75)

model = LinearRegression()
model.fit(Xtr, ytr)

def resplot(y, preds, title):
    plt.scatter(y, preds - y, s=0.3)
    plt.title(title)  
    plt.xlabel("Predictions")
    plt.ylabel("Residuals")
    plt.axhline(0, color='red', linestyle='--', linewidth=0.8)
    plt.show()

train_preds = model.predict(Xtr)
test_preds = model.predict(Xte)

resplot(ytr, train_preds, "Residual Plot (Training Set)")
resplot(yte, test_preds, "Residual Plot (Test Set)")

# %% [markdown]
# **Analysis:** The results show that the model overestimates values between 1 and 3, while underestimating those between 3 and 5.
# Probably a linear model working non-linearly would better approximate our dataframe.
# In particular, we divided the dataframe into two, with the trains being given 75% and the tests the remaining 25%.
# For this reason, we observe a greater presence of points (and thus data) in the upper part, i.e. the train part.

# %% [markdown]
# ### Step 4: Repeat.
#
# Now you should put all of the pieces together into a repeatable, reproducible pipeline.
#
# ### Exercise 4: The Pipeline
# Write a function (or even just code in the cell that calls previously defined functions) that runs an **experiment**:
# 1. Splitting data
# 1. Instantiating the model
# 1. Fitting the model
# 1. Evaluating the model
# 1. (Maybe) Visualizing results
#
# Experiment with different splits to see if the results are the same. Try using more or less training data with respect to test data. Observe how the results change.

# %%
from sklearn.model_selection import train_test_split

def pipeline(df, targets, train_size=0.75, degree = 1):
    
    (Xtr, Xte, ytr, yte) = train_test_split(df, targets, test_size=0.25)
    
    model = LinearRegression()
    model.fit(Xtr, ytr)
    
    preds_tr = model.predict(Xtr)
    preds_te = model.predict(Xte)
    
    rmse_train = np.square(np.subtract(ytr, preds_tr)).mean()
    rmse_test = np.square(np.subtract(yte, preds_te)).mean()
    mae_train = np.abs(np.subtract(ytr, preds_tr)).mean()
    mae_test = np.abs(np.subtract(yte, preds_te)).mean()
    
    print(f'Train size: {train_size}')
    print(f'Degree: {degree}')
    print(f'RMSE on train: {rmse_train:.4f}')
    print(f'RMSE on test: {rmse_test:.4f}')
    print(f'MAE on train: {mae_train:.4f}')
    print(f'MAE on test: {mae_test:.4f}')
    print('--------')
    
    # Plot the data
    plt.figure(figsize=(12, 6))
    plt.scatter(ytr, preds_tr, label='Train Data', alpha=0.5)
    plt.scatter(yte, preds_te, label='Test Data', alpha=0.5)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.title(f'Degree {degree}, Train Size {train_size}')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    
    return rmse_train, rmse_test, mae_train, mae_test

for train_size in range(1, 10, 2):
    train_size /= 10.0  # Convert to a float in the range [0.0, 1.0]
    pipeline(df, targets, train_size)
    print("Train size:", train_size)
    print('--------')
# Out:
# Train size: 0.1
# Degree: 1
# RMSE on train: 0.5170
# RMSE on test: 0.5467
# MAE on train: 0.5275
# MAE on test: 0.5388
# --------
# Train size: 0.1
# --------
# Train size: 0.3
# Degree: 1
# RMSE on train: 0.5237
# RMSE on test: 0.5265
# MAE on train: 0.5320
# MAE on test: 0.5280
# --------
# Train size: 0.3
# --------
# Train size: 0.5
# Degree: 1
# RMSE on train: 0.5306
# RMSE on test: 0.5066
# MAE on train: 0.5348
# MAE on test: 0.5239
# --------
# Train size: 0.5
# --------
# Train size: 0.7
# Degree: 1
# RMSE on train: 0.5278
# RMSE on test: 0.5199
# MAE on train: 0.5334
# MAE on test: 0.5215
# --------
# Train size: 0.7
# --------
# Train size: 0.9
# Degree: 1
# RMSE on train: 0.5311
# RMSE on test: 0.5042
# MAE on train: 0.5350
# MAE on test: 0.5249
# --------
# Train size: 0.9
# --------

# %% [markdown]
# **Analysis:** The code implements a pipeline to train a linear regression model, calculate prediction errors, and visualize the results. The data are divided into training and test sets using different values for the size of the training set, ranging from 0.1 to 0.9 in 0.2 increments.
# To measure performance, RMSE (Root Mean Squared Error) and MAE (Mean Absolute Error) are calculated on both training and test datasets.
#
# Train errors remain fairly stable, varying only slightly between different magnitudes of the train set.
# The test errors fluctuate, indicating that with a small train size (0.1 or 0.3), the model does not have enough data to learn correctly, while intermediate train size values such as 0.7 seem to offer the best compromise.
# In particular, train size 0.7 appears to be the best value in terms of generalization, with the smallest gap between train and test errors.
# If we go to use a train size of 90% the model tends to overfitting, as we see well from the fact that the RMSE on the test is increased compared to the previous train with 0.7 size.
#
# I took the RMSE code from this link (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.root_mean_squared_error.html).

# %% [markdown]
# ---
# ---
# ## Part 2: Improving our Regressor
#
# Now that we have a simple, baseline linear regression result, let's see if we can't improve on it. This is where the real work begins, and where it is **super** important to ensure that the conclusions we draw are *valid*.
#
# **Questions**: Are our independent variables *scaled* similarly? Does our model have *high variance* -- that is, if we fit it to a new training sample, does the result vary dramatically?
#
# ### Exercise 5: Increasing Model Capacity
#
# Check out the documentation for `sklearn.preprocessing.PolynomialFeatures`. Map the independent variables onto a **polynomial** basis of variable order. Fit your model using your pipeline from above and observe its behavior for different degree polynomial embeddings.

# %%
# Your code here.

from sklearn.preprocessing import PolynomialFeatures

rmse_train_values = []
rmse_test_values = []
mae_train_values = []
mae_test_values = []

def variableSizeModels(train_size = 0.75):
    for degree in range(1, 4):
        
        poly = PolynomialFeatures(degree)    # Create PolynomialFeatures instance with the current degree

        df_poly = poly.fit_transform(df)   # Apply the PolynomialFeatures instance to the dataframe
        
        rmse_train, rmse_test, mae_train, mae_test = pipeline(df_poly, targets, train_size=train_size , degree=degree) 
        
        rmse_train_values.append(rmse_train)
        rmse_test_values.append(rmse_test)
        mae_train_values.append(mae_train)
        mae_test_values.append(mae_test)
                

variableSizeModels()
# Out:
# Train size: 0.75
# Degree: 1
# RMSE on train: 0.5280
# RMSE on test: 0.5139
# MAE on train: 0.5333
# MAE on test: 0.5277
# --------
# Train size: 0.75
# Degree: 2
# RMSE on train: 0.4132
# RMSE on test: 10.5139
# MAE on train: 0.4557
# MAE on test: 0.5105
# --------
# Train size: 0.75
# Degree: 3
# RMSE on train: 0.3478
# RMSE on test: 1265.9533
# MAE on train: 0.4208
# MAE on test: 0.9546
# --------

# %% [markdown]
# **Analysis:**
# The implemented linear model provides 3 degrees.
# Grade 1 provides a good baseline with similar errors on both sets.
# Grade 2 improves performance over grade 1 without compromising generalization, suggesting that it may be the best choice among the three models.
# Grade 3 is overly complex for the available data, causing extreme overfitting, with poor performance on the test set.
#
# I took my cue from this link (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html) to implement the function poly.fit_transform(df).

# %% [markdown]
# ### Exercise 6: Hyperparameter Selection and Cross-validation
#
# How should we select the correct *degree* for our polynomial basis? Is the performance on the *training* set equal to the performance on the *test* set? Why?

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score


def variableSizeModels2(df, targets, train_size=0.75):
    avg_mse_per_degree = []
    degrees = range(1, 6)  # Testing degrees from 1 to 5
    
    for degree in degrees:
        
        poly = PolynomialFeatures(degree)    # Create PolynomialFeatures instance with the current degree
        df_poly = poly.fit_transform(df)   # Apply the PolynomialFeatures instance to the dataframe
        
        (Xtr, Xte, ytr, yte) = train_test_split(df_poly, targets, train_size=train_size, random_state=42)    
        
        model = LinearRegression()
        model.fit(Xtr, ytr)
        
        # Perform k-fold cross-validation and calculate mean squared error (MSE)
        mse_scores = cross_val_score(model, Xtr, ytr, scoring="neg_mean_squared_error", cv=5)
        mse_scores = -mse_scores  # Convert negative MSE to positive
        
        print("Current degree:", degree)
        for fold, mse in enumerate(mse_scores, 1):
            print(f'Fold {fold}: MSE = {mse:.4f}')
            
        average_mse = np.mean(mse_scores)
        avg_mse_per_degree.append(average_mse)
        print(f'Average MSE: {average_mse:.4f}')
        
        # Perform grid search to tune model hyperparameters
        param_grid = {
            'fit_intercept': [True, False],
        }
        grid_search = GridSearchCV(model, param_grid, scoring="neg_mean_squared_error", cv=5)
        grid_search.fit(Xtr, ytr)

        best_params = grid_search.best_params_
        print(f'Best Hyperparameters: {best_params}')

        # Evaluate the best model on the test data
        mse_test = -grid_search.score(Xte, yte)
        print(f'Best Model MSE on Test Data: {mse_test:.4f}')
        print('--------')

# Call the function with your data and targets
variableSizeModels2(df, targets)
# Out:
# Current degree: 1
# Fold 1: MSE = 0.5446
# Fold 2: MSE = 0.4825
# Fold 3: MSE = 0.5394
# Fold 4: MSE = 0.5101
# Fold 5: MSE = 0.5446
# Average MSE: 0.5242
# Best Hyperparameters: {'fit_intercept': False}
# Best Model MSE on Test Data: 0.5411
# --------
# Current degree: 2
# Fold 1: MSE = 0.9163
# Fold 2: MSE = 0.4063
# Fold 3: MSE = 343.4615
# Fold 4: MSE = 0.4204
# Fold 5: MSE = 2.8764
# Average MSE: 69.6162
# Best Hyperparameters: {'fit_intercept': False}
# Best Model MSE on Test Data: 0.4548
# --------
# Current degree: 3
# Fold 1: MSE = 0.9900
# Fold 2: MSE = 1.9597
# Fold 3: MSE = 1405023.6770
# Fold 4: MSE = 30.5870
# Fold 5: MSE = 0.4355
# Average MSE: 281011.5298
# Best Hyperparameters: {'fit_intercept': False}
# Best Model MSE on Test Data: 21.3435
# --------
# Current degree: 4
# Fold 1: MSE = 1802.7839
# Fold 2: MSE = 117.9655
# Fold 3: MSE = 1797846620237.5747
# Fold 4: MSE = 6354.7052
# Fold 5: MSE = 408718036.1975
# Average MSE: 359651069309.8453
# Best Hyperparameters: {'fit_intercept': True}
# Best Model MSE on Test Data: 2690.9474
# --------
# Current degree: 5
# Fold 1: MSE = 242.2211
# Fold 2: MSE = 77.2330
# Fold 3: MSE = 830161661.0000
# Fold 4: MSE = 31.6773
# Fold 5: MSE = 154686656.0383
# Average MSE: 196969733.6339
# Best Hyperparameters: {'fit_intercept': True}
# Best Model MSE on Test Data: 15886.6029
# --------

# %% [markdown]
# **Final Analysis:** We divide the analysis into two parts.
# To find the Best Polynomial Degree we have the following results:Degree 1 gives stable performance with low MSE on both the cross-validation and test sets.
# Degree 2 shows more variability in cross-validation but gives the best performance on the test set. This suggests that grade 2 captures significant relationships in the data that a linear model (grade 1) cannot capture.
# Grades 3, 4 and 5 introduce extreme overfitting, with errors in cross-validation and testing skyrocketing.
#
# Regarding Best Hyperparameter Setting (fit_intercept):
# For grades 1 and 2, fit_intercept=False is consistently selected by grid search, indicating that the intercept term does not contribute significantly to model performance for these simpler models.
# For the higher grades (4 and 5), fit_intercept=True is selected, but these models are overpowered and perform poorly on the test set.
#
# The best model for this dataset remains grade 2 with fit_intercept=False. Despite some instability in the cross-validation results, its MSE on the test set of 0.4548 is the lowest among all the models tested.
# Grade 1 is also a strong candidate because of its stability, but its MSE on the test set is slightly worse than that of Grade 2. Therefore, Grade 2 balances complexity and complexity. Therefore, grade 2 is best suited to balance complexity and generalization for this dataset.

# %% [markdown]
# ---
# ---
#
# ## Part 3: Optional
#
# ### Exercise 7 (BONUS): Ordinary Least Squares with Gradient Descent
# This is an *optional* exercise, but I think everyone should implement gradient descent at least once in their life, so if you like a challenge this assignment can earn you up to five (5) bonus points our of 100 on this assignment.
#
# #### Exercise 7.1: The Loss Function
# Recall that the loss function for parameters $\mathbf{w}$ on dataset $\mathcal{D} = \{ (\mathbf{x}_n, y_n)\}_{n=1}^{N}$ we use for least squares regression is (assume that the inputs $\mathbf{x}$ have already been augmented with $x_0 = 1$ to account for the bias parameter $w_0$):
# $$
# \mathcal{L}(\mathcal{D}, \mathbf{w}) = \frac{1}{2} \sum_{n=1}^{N} (\mathbf{w}^T \mathbf{x}_n - y_n)^2
# $$
#
# Start by implementing a function `error(w, Xs, ys)` that computes this loss function. This function should be *independent* of feature dimensionality and **do not use loops**!
#
# Test this function using data from the California Housing dataset (after augmenting it with a constant 1 in the first dimension!) with the parmaters $\mathbf{w}$ set to the solution found by `LinearRegression`. Compare it to randomly initialized $\mathbf{w}$.

# %%
# Define the error function
def error(w, Xs, ys):
    # Compute the predictions for all data points
    predictions = np.dot(Xs, w)
    
    # Compute the residuals (predicted - actual values)
    residuals = predictions - ys
    
    # Compute the squared error and take the sum, then divide by 2
    loss = 0.5 * np.sum(residuals ** 2)
    
    return loss

# Load California housing dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Add a bias term (column of 1s) to the design matrix X
X = np.hstack([np.ones((X.shape[0], 1)), X])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Fit the LinearRegression model
model = LinearRegression()
model.fit(X_train, y_train)

# Use only the coefficients (since the bias is included in the X matrix)
w_learned = model.coef_

# Compute the loss using the learned weights
train_loss_learned = error(w_learned, X_train, y_train)
test_loss_learned = error(w_learned, X_test, y_test)

print(f'Learned weights - Training Loss: {train_loss_learned:.4f}, Test Loss: {test_loss_learned:.4f}')

w_random = np.random.randn(X_train.shape[1])

train_loss_random = error(w_random, X_train, y_train)
test_loss_random = error(w_random, X_test, y_test)

print(f'Random weights - Training Loss: {train_loss_random:.4f}, Test Loss: {test_loss_random:.4f}')
# Out:
# Learned weights - Training Loss: 10616033.5956, Test Loss: 3538509.2810
# Random weights - Training Loss: 22040372773.6253, Test Loss: 7099712157.0893

# %% [markdown]
# **Analysis:** The trained model is definitely doing a better job than the random weights, as shown by the difference in losses. However, the discrepancy between the loss on the training and the loss on the test is interesting. Generally, you would expect the loss on training to be lower than the loss on testing, because the model sees the training data during training. The reason why your result is different could be:
# * Noise in the training set: The training data might have more variability or noise than the test data.
# * Random splitting: Depending on how the data was split, some of the more complex or noisy samples may have been included in the training set, increasing the loss on that set.
#
# The difference between the two scenarios highlights that a model trained with an optimisation procedure (linear regression in our case) is much more effective in reducing error than a model with random parameters.

# %% [markdown]
# #### Exercise 7.2: The Gradient of the Loss Function
# Now we need the *gradient* of the loss function in order to improve our solution. Recall that the gradient of the loss is:
# $$
# \begin{align*}
# \nabla_{\mathbf{w}} \mathcal{L}(\mathcal{D}, \mathbf{w}) &= \nabla_{\mathbf{w}} \frac{1}{2} \sum_{n=1}^{N} (\mathbf{w}^T \mathbf{x}_n - y_n)^2 \\
# &= \frac{1}{2} \sum_{n=1}^{N} \nabla_{\mathbf{w}} (\mathbf{w}^T \mathbf{x}_n - y_n)^2 \quad \text{(by linearity of the gradient)} \\
# &= \sum_{n=1}^{N} (\mathbf{w}^T \mathbf{x}_n - y_n) \nabla_{\mathbf{w}} (\mathbf{w}^T \mathbf{x}_n) \quad \text{(by gradient rule for quadratics and chain rule)}
# \end{align*}
# $$
# Write a Python function `grad_error(w, Xs, ys)` to compute this gradient of the loss function for a given $\mathbf{w}$ and dataset $\mathcal{D}$. Again, if you find yourself writing loops, your probably doing something wrong!

# %%
# Define the gradient of the error function
def grad_error(w, Xs, ys):
    # Compute the residual (predicted - actual values)
    residuals = np.dot(Xs, w) - ys
    
    # Compute the gradient as X^T * residuals
    grad = np.dot(Xs.T, residuals)
    
    return grad

# Load California housing dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Add a bias term (column of 1s) to the design matrix X
X = np.hstack([np.ones((X.shape[0], 1)), X])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Fit the LinearRegression model
model = LinearRegression()
model.fit(X_train, y_train)

# Use only the coefficients (since the bias is included in the X matrix)
w_learned = model.coef_

# Compute the gradient using the learned weights
grad_learned = grad_error(w_learned, X_train, y_train)
print("Gradient using learned weights:")
print(grad_learned)

# Compare with randomly initialized weights
w_random = np.random.randn(X_train.shape[1])

# Compute the gradient using random weights
grad_random = grad_error(w_random, X_train, y_train)
print("\nGradient using random weights:")
print(grad_random)
# Out:
# Gradient using learned weights:
# [ 5.73190771e+05  2.22301386e+06  1.63909603e+07  3.11563483e+06
#   6.28722159e+05  8.18228270e+08  1.78070866e+06  2.04323707e+07
#  -6.85442937e+07]
#
# Gradient using random weights:
# [-7.62388417e+06 -2.96478214e+07 -1.95597478e+08 -4.03424203e+07
#  -8.16863931e+06 -1.79775069e+10 -2.95891894e+07 -2.70463238e+08
#   9.10583763e+08]

# %% [markdown]
# **Analysis:** The gradients calculated with the learned weights show a much lower value than the random ones. This is a good sign, it implies that the trained model has found a more useful updating direction to minimise the error.

# %% [markdown]
# #### Exercise 7.3: Gradient Descent
# Now we have everything we need to, starting from a randomly initialized $\mathbf{w}$ and some data $\mathcal{D}$, iteratively improve our solution (up to some numerical tolerance). Recall that our gradient descent update rule is:
# $$
# \mathbf{w}_{t+1} = \mathbf{w}_t - \eta \nabla_{\mathbf{w}} \mathcal{L}(\mathcal{D}, \mathbf{w}_{t})
# $$
# Write a Python function `gradient_descent(w, Xs, ys, eta, tol=1e-5)` to perform gradient descent to convergence (i.e. until the total loss between iterations is less than `tol`). Here you can use a loop.

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# Gradient of the error function
def grad_error(w, Xs, ys):
    residuals = np.dot(Xs, w) - ys
    grad = np.dot(Xs.T, residuals)
    return grad

# Error function (loss)
def error(w, Xs, ys):
    predictions = np.dot(Xs, w)
    residuals = predictions - ys
    loss = 0.5 * np.sum(residuals ** 2)
    return loss

# Gradient Descent Algorithm with Gradient Clipping
def gradient_descent(w, Xs, ys, eta, tol=1e-5, max_iter=1000, clip_value=100):
    prev_loss = error(w, Xs, ys)
    for i in range(max_iter):
        # Compute the gradient of the loss
        grad = grad_error(w, Xs, ys)
        
        # Clip the gradient to avoid overflow
        grad = np.clip(grad, -clip_value, clip_value)
        
        # Update the weights using the gradient
        w = w - eta * grad
        
        # Compute the new loss
        curr_loss = error(w, Xs, ys)
        
        # Check for convergence (if loss improvement is below tolerance)
        if abs(prev_loss - curr_loss) < tol:
            print(f'Converged after {i+1} iterations.')
            break
        
        prev_loss = curr_loss

    return w

# Load California housing dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Normalize the data using StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Add a bias term (column of 1s) to the design matrix X
X_scaled = np.hstack([np.ones((X_scaled.shape[0], 1)), X_scaled])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=42)

# Initialize weights with smaller random values
w_random = np.random.randn(X_train.shape[1]) * 0.01  # Smaller initialization

# Run gradient descent with a smaller learning rate and gradient clipping
learning_rate = 1e-6  # Smaller learning rate
w_optimized = gradient_descent(w_random, X_train, y_train, eta=learning_rate)

# Output the final optimized weights
print("Optimized weights from gradient descent:")
print(w_optimized)
# Out:
# Optimized weights from gradient descent:
# [ 0.09858226  0.10509823  0.09431611  0.10641396 -0.09046521  0.00055059
#  -0.01910112 -0.11447216 -0.10589012]

# %% [markdown]
# **Analysis:** The weights are divided into positive and negative.
# The weights with positive value, indicating that these features contribute positively to the prediction of the target variable (house price).
# Negative weights suggest that these features have a negative effect on the forecast.
# In fact, each weight represents the impact of an independent variable on the dependent variable.

# %% [markdown]
# Now use your implementation of gradient descent to solve the regression problem for the California Housing dataset. You will probably have to play with different learning rates, but verify that you end up with a solution (very) close to the one found by Scikit-learn's `LinearRegression` class.

# %%
# Funzione per calcolare l'errore quadratico medio (MSE)
def mean_squared_error_custom(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# Gradient of the error function
def grad_error(w, Xs, ys):
    residuals = np.dot(Xs, w) - ys
    grad = np.dot(Xs.T, residuals)
    return grad

# Error function (loss)
def error(w, Xs, ys):
    predictions = np.dot(Xs, w)
    residuals = predictions - ys
    loss = 0.5 * np.sum(residuals ** 2)
    return loss

# Gradient Descent Algorithm with Gradient Clipping
def gradient_descent(w, Xs, ys, eta, tol=1e-5, max_iter=1000, clip_value=100):
    prev_loss = error(w, Xs, ys)
    for i in range(max_iter):
        # Compute the gradient of the loss
        grad = grad_error(w, Xs, ys)
        
        # Clip the gradient to avoid overflow
        grad = np.clip(grad, -clip_value, clip_value)
        
        # Update the weights using the gradient
        w = w - eta * grad
        
        # Compute the new loss
        curr_loss = error(w, Xs, ys)
        
        # Check for convergence (if loss improvement is below tolerance)
        if abs(prev_loss - curr_loss) < tol:
            print(f'Converged after {i+1} iterations.')
            break
        
        prev_loss = curr_loss

    return w

# Load California housing dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Normalize the data using StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Add a bias term (column of 1s) to the design matrix X
X_scaled = np.hstack([np.ones((X_scaled.shape[0], 1)), X_scaled])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=42)

# Step 1: Use Scikit-learn's LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)

# Get the weights (coefficients and intercept) from the LinearRegression model
w_sklearn = np.hstack([linear_reg.intercept_, linear_reg.coef_])
print("Scikit-learn Linear Regression weights:")
print(w_sklearn)

# Step 2: Run gradient descent with a smaller learning rate and gradient clipping
np.random.seed(42)
w_random = np.random.randn(X_train.shape[1]) * 0.01  # Smaller initialization

# Experimenting with different learning rates
learning_rate = 1e-4  # Try different values such as 1e-4, 1e-5, 1e-6
w_optimized = gradient_descent(w_random, X_train, y_train, eta=learning_rate)

# Output the final optimized weights
print("\nOptimized weights from gradient descent:")
print(w_optimized)

# Compare performance (mean squared error) between Scikit-learn and custom gradient descent
y_pred_sklearn = linear_reg.predict(X_test)
y_pred_gd = np.dot(X_test, w_optimized)

mse_sklearn = mean_squared_error_custom(y_test, y_pred_sklearn)
mse_gd = mean_squared_error_custom(y_test, y_pred_gd)

# Calculate the difference between the two MSEs
mse_difference = abs(mse_sklearn - mse_gd)

print(f"\nMean Squared Error (Scikit-learn): {mse_sklearn}")
print(f"Mean Squared Error (Gradient Descent): {mse_gd}")
print(f"Difference in Mean Squared Error: {mse_difference}")
# Out:
# Scikit-learn Linear Regression weights:
# [ 2.06826812e+00  0.00000000e+00  8.50339731e-01  1.20409732e-01
#  -3.08660358e-01  3.76499432e-01 -1.62960292e-03 -3.57591325e-02
#  -8.93992446e-01 -8.68319902e-01]
#
# Optimized weights from gradient descent:
# [ 2.06821422  0.83580303  0.12846245 -0.28404039  0.34196047 -0.00458233
#  -0.04044615 -0.87203733 -0.85646055]
#
# Mean Squared Error (Scikit-learn): 0.5411287478470688
# Mean Squared Error (Gradient Descent): 0.5372317973766996
# Difference in Mean Squared Error: 0.003896950470369198

# %% [markdown]
# **Analysis:**
# The weights provided by Scikit-learn show some correspondence with those obtained by gradient descent, but there are differences in the specific values. This is normal, as optimisation methods and random initialisations can produce slightly different weights.
#
# Although the weights obtained by gradient descent are similar, there are some variations. The small differences may result from various factors, including different initialisation and learning rate.
#
# The MSE for the Scikit-learn model is 0.5411, while for the gradient descent model it is 0.5372. This indicates that the gradient descent model has a slightly lower error, which suggests good optimisation.
#
#
# The gradient descent algorithm performed well, producing results comparable to those of Scikit-learn, and convergence was achieved after a reasonable number of iterations.
# The small difference in error suggests that both methods are valid, but Scikit-learn offers a more optimised and faster solution.

# %% [markdown]
# For this last section, I got help from Chatgpt Version 4 (the most recent and free), particularly for some parts where I then adjusted the code provided by it. It did not always provide exactly what I wanted but with my adjustments it was effective.
